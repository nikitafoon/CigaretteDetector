# %%
from pathlib import Path
import torch
from torch.utils.data import Dataset, DataLoader
import random
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import albumentations as A
from albumentations.pytorch import ToTensorV2
import glob
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pytorch_lightning as pl
import torchmetrics
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint
import cv2 as cv
from ultralytics import YOLO

# %% [markdown]
# ### Seed

# %%
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# ### Path

# %%
test_dir = Path("test/*")
test_mask_dir = Path("test_mask/labels/Test/*")
test_data = Path("test_mask/data.yaml")

val_dir = Path("val/*")
val_mask_dir = Path("test_mask/labels/Test")
val_data = Path("test_mask/data.yaml")

train_dir = Path("train/*")
train_mask_dir = Path("train_mask/labels/Train/*")
train_data = Path("train_mask/data.yaml")

all_data = Path("all_data/data.yaml")

# %% [markdown]
# ### Model

# %%
model = YOLO('yolov8n.pt')

# %%
result = model.train(
    data=all_data,
    epochs=100,
    imgsz=640,
    device=0,
    batch=16
)
# Out:
# Ultralytics 8.4.49 🚀 Python-3.13.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 7706MiB)
# ...
